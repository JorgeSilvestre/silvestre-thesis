# %% [markdown]
# ## Setup

# %%
# Required libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(12,5)}) # just changing figure size

# %% [markdown]
# First I will create a 'data' folder on which we will store the final aggregated datasets in csv format.

# %%
# !mkdir data
# !mkdir data/trayectorias

# %% [markdown]
# # For cloning a specific subfolder, better use subversion (git cannot)

# %%
# !sudo apt install subversion
# !sudo svn export https://github.com/google-research/google-research/trunk/tft
# Out:
# [sudo] contraseña para gsi:
# [sudo] contraseña para gsi:

# %%
# check that the "tft" folder has been added to the tfm drive folder
# !ls tft
# Out:
# data_formatters  README.md	   script_download_data.py
# expt_settings	 requirements.txt  script_hyperparam_opt.py
# libs		 run.sh		   script_train_fixed_params.py

# %% [markdown]
# ### Importing the GoogleResearch' TFT processing library

# %%
# %cd tft
# Out:
# /home/gsi/Descargas/tft

# %%
# Making sure all needed libraries of Google lib and exact versions are matched
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy>=1.17.4 in /home/gsi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (1.21.5)
# Requirement already satisfied: pandas>=0.25.3 in /home/gsi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: scikit-learn>=0.22 in /home/gsi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.2.2)
# Collecting tensorflow-probability>=0.8.0
#   Downloading tensorflow_probability-0.20.1-py2.py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 37.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting wget>=3.2
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyunpack>=0.1.2
#   Downloading pyunpack-0.3-py2.py3-none-any.whl (4.1 kB)
# Collecting patool>=1.12
#   Downloading patool-1.12-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gsi/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.3->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gsi/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.3->-r requirements.txt (line 2)) (2022.7)
# Requirement already satisfied: joblib>=1.1.1 in /home/gsi/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/gsi/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->-r requirements.txt (line 3)) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gsi/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->-r requirements.txt (line 3)) (2.2.0)
# Requirement already satisfied: decorator in /home/gsi/anaconda3/lib/python3.9/site-packages (from tensorflow-probability>=0.8.0->-r requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: six>=1.10.0 in /home/gsi/anaconda3/lib/python3.9/site-packages (from tensorflow-probability>=0.8.0->-r requirements.txt (line 4)) (1.16.0)
# Collecting dm-tree
#   Downloading dm_tree-0.1.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 22.8 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle>=1.3 in /home/gsi/anaconda3/lib/python3.9/site-packages (from tensorflow-probability>=0.8.0->-r requirements.txt (line 4)) (2.2.1)
# Collecting gast>=0.3.2
#   Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting absl-py
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 38.3 MB/s eta 0:00:00
# Collecting easyprocess
#   Downloading EasyProcess-1.1-py3-none-any.whl (8.7 kB)
# Collecting entrypoint2
#   Downloading entrypoint2-1.1-py2.py3-none-any.whl (9.9 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=08f689f652884dcde96296d07dc0dbfe9627f91b1fa80c03bad5abf3250ba5ac
#   Stored in directory: /home/gsi/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# Installing collected packages: wget, patool, entrypoint2, easyprocess, dm-tree, pyunpack, gast, absl-py, tensorflow-probability
# Successfully installed absl-py-1.4.0 dm-tree-0.1.8 easyprocess-1.1 entrypoint2-1.1 gast-0.5.4 patool-1.12 pyunpack-0.3 tensorflow-probability-0.20.1 wget-3.2
