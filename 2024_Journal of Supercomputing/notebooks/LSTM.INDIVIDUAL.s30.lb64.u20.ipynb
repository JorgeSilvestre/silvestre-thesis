# %%
import tensorflow as tf
import pandas as pd
import datetime
import matplotlib.pyplot as plt

import sys
sys.path.append('./rtaUtils')

from rtaUtils import paths, experiment, data_loading

# import wandb, os
# from wandb.keras import WandbCallback
# os.environ["WANDB_SILENT"] = "true"

tf.config.set_visible_devices([], 'GPU')
visible_devices = tf.config.get_visible_devices()
print(visible_devices)
for device in visible_devices:
    assert device.device_type != 'GPU'
    
### Features ##################################################################
numeric_feat = [
    'latitude', 'longitude', 'altitude', 'departureDelay', 'vspeed', 'speed', 
    'day_of_week', 'track', 'wind_dir_degrees', 'wind_speed_kt', 
    'visibility_statute_mi', 'max_temp', 'min_temp', 'clouds', 'hav_distance'
]
categoric_feat = [
    'time_of_day', 'operator', 'aerodromeOfDeparture', 'sky_status'
]
objective = ['RTA']

ts_features = [
    'latitude', 'longitude', 'altitude', 'vspeed', 'speed', 'track', 'hav_distance'
]
nts_features = [
    'departureDelay', 'day_of_week', 'wind_dir_degrees','wind_speed_kt', 
    'visibility_statute_mi', 'max_temp', 'min_temp', 'time_of_day', 'operator', 
    'aerodromeOfDeparture', 'sky_status', 'clouds'
]

feat_dict = dict(
    numeric=numeric_feat,
    categoric=categoric_feat,
    objective=objective,
    ts=ts_features,
    nts=nts_features
)

airport_list = ( 
                'LEBL','LPPT','LFPO','LFPG','EGLL','LPPR','EDDF','EBBR','EHAM','LEBB','LIRF',
                'EDDM','EGKK','LEVC','LSGG','LECO','LIMC','EIDW','LFML','LEZL','LOWW','LIPZ',
                'LIPE','LFLL','EDDL','EDDB','LTFM','LFMN','LFRS','LROP','EDDP','LGAV','EDDH',
                'LHBP','EKCH','EGCC','ELLX',
                'LKPR','LIRN','LBSF','EPWA')
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
### Experiment setup ##########################################################
n_units      = 20
lookback     = 64
sampling     = 30

epochs       = 40

act_function = 'tanh'
batch_size   = 128
from_parquet = True

model_config = dict(
    n_units=n_units,
    act_function=act_function,
    batch_size=batch_size,
)

# %% [markdown]
# ## Entrenamiento

# %%
for airport in airport_list:
    print(airport.center(6).center(100, '#'))
    ### Model configuration #######################################################
    model_type   = f'LSTM_{airport}'
    months       = '*' # 20220[12]
    # airport      = 'EDDF'
    glob_text    = f'{months}-{airport}'

    experimento = experiment.ExperimentVanilla(
        lookback=lookback,
        sampling=sampling,
        model_config=model_config,
        months=months, 
        airport=airport,
        features=feat_dict,
        model_type=model_type
    )
    experimento.init_model()
    # experimento.load_model()
    # experimento.model.summary()

    history = experimento.train(epochs=epochs, from_parquet=from_parquet, add_callbacks = [])
# Out:
# ############################################### LKPR ###############################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Epoch 1/40
# 242/242 [==============================] - 12s 38ms/step - loss: 0.0300 - mean_squared_error: 0.0022 - val_loss: 0.0177 - val_mean_squared_error: 4.5952e-04
# Epoch 2/40
# 242/242 [==============================] - 9s 37ms/step - loss: 0.0123 - mean_squared_error: 2.5891e-04 - val_loss: 0.0113 - val_mean_squared_error: 2.5792e-04
# Epoch 3/40
# 242/242 [==============================] - 12s 50ms/step - loss: 0.0107 - mean_squared_error: 1.9878e-04 - val_loss: 0.0102 - val_mean_squared_error: 2.0631e-04
# Epoch 4/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0099 - mean_squared_error: 1.6833e-04 - val_loss: 0.0103 - val_mean_squared_error: 2.1169e-04
# Epoch 5/40
# 242/242 [==============================] - 12s 47ms/step - loss: 0.0098 - mean_squared_error: 1.6252e-04 - val_loss: 0.0104 - val_mean_squared_error: 2.1760e-04
# Epoch 6/40
# 242/242 [==============================] - 11s 47ms/step - loss: 0.0094 - mean_squared_error: 1.5324e-04 - val_loss: 0.0107 - val_mean_squared_error: 2.1418e-04
# Epoch 7/40
# 242/242 [==============================] - 12s 47ms/step - loss: 0.0092 - mean_squared_error: 1.4665e-04 - val_loss: 0.0113 - val_mean_squared_error: 2.0861e-04
# Epoch 8/40
# 242/242 [==============================] - 12s 47ms/step - loss: 0.0091 - mean_squared_error: 1.4342e-04 - val_loss: 0.0106 - val_mean_squared_error: 2.2146e-04
# Epoch 9/40
# 242/242 [==============================] - 12s 47ms/step - loss: 0.0089 - mean_squared_error: 1.3598e-04 - val_loss: 0.0110 - val_mean_squared_error: 2.3459e-04
# Epoch 10/40
# 242/242 [==============================] - 12s 47ms/step - loss: 0.0090 - mean_squared_error: 1.3979e-04 - val_loss: 0.0111 - val_mean_squared_error: 2.6150e-04
# Epoch 11/40
# 242/242 [==============================] - 12s 47ms/step - loss: 0.0089 - mean_squared_error: 1.3921e-04 - val_loss: 0.0113 - val_mean_squared_error: 2.4864e-04
# Epoch 12/40
# 242/242 [==============================] - 12s 47ms/step - loss: 0.0089 - mean_squared_error: 1.3749e-04 - val_loss: 0.0117 - val_mean_squared_error: 2.6263e-04
# Epoch 13/40
# 242/242 [==============================] - 12s 47ms/step - loss: 0.0087 - mean_squared_error: 1.3363e-04 - val_loss: 0.0123 - val_mean_squared_error: 2.5381e-04
# Epoch 14/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0085 - mean_squared_error: 1.2963e-04 - val_loss: 0.0118 - val_mean_squared_error: 2.6456e-04
# Epoch 15/40
# 242/242 [==============================] - 12s 47ms/step - loss: 0.0088 - mean_squared_error: 1.3555e-04 - val_loss: 0.0120 - val_mean_squared_error: 2.7977e-04
# Epoch 16/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0085 - mean_squared_error: 1.2924e-04 - val_loss: 0.0123 - val_mean_squared_error: 2.7518e-04
# Epoch 17/40
# 242/242 [==============================] - 12s 47ms/step - loss: 0.0085 - mean_squared_error: 1.2906e-04 - val_loss: 0.0123 - val_mean_squared_error: 2.7504e-04
# Epoch 18/40
# 242/242 [==============================] - 12s 47ms/step - loss: 0.0083 - mean_squared_error: 1.2526e-04 - val_loss: 0.0139 - val_mean_squared_error: 2.8368e-04
# Epoch 19/40
# 242/242 [==============================] - 12s 47ms/step - loss: 0.0083 - mean_squared_error: 1.2602e-04 - val_loss: 0.0120 - val_mean_squared_error: 2.7090e-04
# Epoch 20/40
# 242/242 [==============================] - 12s 47ms/step - loss: 0.0085 - mean_squared_error: 1.2991e-04 - val_loss: 0.0130 - val_mean_squared_error: 2.7612e-04
# Epoch 21/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0085 - mean_squared_error: 1.2833e-04 - val_loss: 0.0130 - val_mean_squared_error: 2.7760e-04
# Epoch 22/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0084 - mean_squared_error: 1.2598e-04 - val_loss: 0.0131 - val_mean_squared_error: 2.8066e-04
# Epoch 23/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0083 - mean_squared_error: 1.2386e-04 - val_loss: 0.0136 - val_mean_squared_error: 2.8814e-04
# Epoch 24/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0082 - mean_squared_error: 1.2158e-04 - val_loss: 0.0129 - val_mean_squared_error: 2.9507e-04
# Epoch 25/40
# 242/242 [==============================] - 12s 49ms/step - loss: 0.0083 - mean_squared_error: 1.2391e-04 - val_loss: 0.0130 - val_mean_squared_error: 2.7740e-04
# Epoch 26/40
# 242/242 [==============================] - 12s 49ms/step - loss: 0.0081 - mean_squared_error: 1.1874e-04 - val_loss: 0.0135 - val_mean_squared_error: 2.9560e-04
# Epoch 27/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0084 - mean_squared_error: 1.2525e-04 - val_loss: 0.0137 - val_mean_squared_error: 2.8042e-04
# Epoch 28/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0080 - mean_squared_error: 1.1675e-04 - val_loss: 0.0129 - val_mean_squared_error: 3.0398e-04
# Epoch 29/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0081 - mean_squared_error: 1.1930e-04 - val_loss: 0.0135 - val_mean_squared_error: 3.0308e-04
# Epoch 30/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0080 - mean_squared_error: 1.1810e-04 - val_loss: 0.0134 - val_mean_squared_error: 3.0334e-04
# Epoch 31/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0082 - mean_squared_error: 1.1942e-04 - val_loss: 0.0125 - val_mean_squared_error: 3.2437e-04
# Epoch 32/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0082 - mean_squared_error: 1.2072e-04 - val_loss: 0.0129 - val_mean_squared_error: 3.2718e-04
# Epoch 33/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0082 - mean_squared_error: 1.1805e-04 - val_loss: 0.0127 - val_mean_squared_error: 3.4680e-04
# Epoch 34/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0082 - mean_squared_error: 1.1991e-04 - val_loss: 0.0126 - val_mean_squared_error: 3.0648e-04
# Epoch 35/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0084 - mean_squared_error: 1.2245e-04 - val_loss: 0.0129 - val_mean_squared_error: 3.4192e-04
# Epoch 36/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0081 - mean_squared_error: 1.1610e-04 - val_loss: 0.0129 - val_mean_squared_error: 3.6024e-04
# Epoch 37/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0080 - mean_squared_error: 1.1472e-04 - val_loss: 0.0128 - val_mean_squared_error: 3.3679e-04
# Epoch 38/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0081 - mean_squared_error: 1.1529e-04 - val_loss: 0.0125 - val_mean_squared_error: 3.1573e-04
# Epoch 39/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0080 - mean_squared_error: 1.1413e-04 - val_loss: 0.0128 - val_mean_squared_error: 3.4581e-04
# Epoch 40/40
# 242/242 [==============================] - 12s 48ms/step - loss: 0.0078 - mean_squared_error: 1.0881e-04 - val_loss: 0.0127 - val_mean_squared_error: 3.4233e-04
# ############################################### LIRN ###############################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Epoch 1/40
# 202/202 [==============================] - 13s 50ms/step - loss: 0.0317 - mean_squared_error: 0.0029 - val_loss: 0.0127 - val_mean_squared_error: 2.6685e-04
# Epoch 2/40
# 202/202 [==============================] - 10s 47ms/step - loss: 0.0127 - mean_squared_error: 3.1156e-04 - val_loss: 0.0116 - val_mean_squared_error: 1.9843e-04
# Epoch 3/40
# 202/202 [==============================] - 10s 47ms/step - loss: 0.0113 - mean_squared_error: 2.5523e-04 - val_loss: 0.0102 - val_mean_squared_error: 1.8563e-04
# Epoch 4/40
# 202/202 [==============================] - 10s 47ms/step - loss: 0.0104 - mean_squared_error: 2.3081e-04 - val_loss: 0.0143 - val_mean_squared_error: 3.0760e-04
# Epoch 5/40
# 202/202 [==============================] - 10s 47ms/step - loss: 0.0102 - mean_squared_error: 2.2291e-04 - val_loss: 0.0136 - val_mean_squared_error: 2.9035e-04
# Epoch 6/40
# 202/202 [==============================] - 15s 73ms/step - loss: 0.0106 - mean_squared_error: 2.3288e-04 - val_loss: 0.0148 - val_mean_squared_error: 3.3275e-04
# Epoch 7/40
# 202/202 [==============================] - 13s 63ms/step - loss: 0.0101 - mean_squared_error: 2.2138e-04 - val_loss: 0.0144 - val_mean_squared_error: 2.8823e-04
# Epoch 25/40
# 202/202 [==============================] - 13s 63ms/step - loss: 0.0090 - mean_squared_error: 1.9317e-04 - val_loss: 0.0098 - val_mean_squared_error: 1.8121e-04
# Epoch 26/40
# 202/202 [==============================] - 13s 62ms/step - loss: 0.0090 - mean_squared_error: 1.9058e-04 - val_loss: 0.0095 - val_mean_squared_error: 1.3686e-04
# Epoch 27/40
# 202/202 [==============================] - 15s 71ms/step - loss: 0.0089 - mean_squared_error: 1.8719e-04 - val_loss: 0.0110 - val_mean_squared_error: 2.1189e-04
# Epoch 28/40
# 202/202 [==============================] - 14s 69ms/step - loss: 0.0090 - mean_squared_error: 1.9128e-04 - val_loss: 0.0104 - val_mean_squared_error: 1.9145e-04
# Epoch 29/40
# 202/202 [==============================] - 13s 64ms/step - loss: 0.0090 - mean_squared_error: 1.9384e-04 - val_loss: 0.0111 - val_mean_squared_error: 2.1266e-04
# Epoch 30/40
# 202/202 [==============================] - 14s 66ms/step - loss: 0.0090 - mean_squared_error: 1.9407e-04 - val_loss: 0.0104 - val_mean_squared_error: 1.9426e-04
# Epoch 31/40
# 202/202 [==============================] - 10s 48ms/step - loss: 0.0090 - mean_squared_error: 1.9209e-04 - val_loss: 0.0084 - val_mean_squared_error: 1.2364e-04
# Epoch 32/40
# 202/202 [==============================] - 10s 49ms/step - loss: 0.0087 - mean_squared_error: 1.8695e-04 - val_loss: 0.0110 - val_mean_squared_error: 1.7130e-04
# Epoch 33/40
# 202/202 [==============================] - 10s 48ms/step - loss: 0.0090 - mean_squared_error: 1.9189e-04 - val_loss: 0.0096 - val_mean_squared_error: 1.6968e-04
# Epoch 34/40
# 202/202 [==============================] - 10s 49ms/step - loss: 0.0088 - mean_squared_error: 1.8645e-04 - val_loss: 0.0084 - val_mean_squared_error: 1.2392e-04
# Epoch 35/40
# 202/202 [==============================] - 10s 48ms/step - loss: 0.0085 - mean_squared_error: 1.8394e-04 - val_loss: 0.0109 - val_mean_squared_error: 2.0191e-04
# Epoch 36/40
# 202/202 [==============================] - 10s 49ms/step - loss: 0.0087 - mean_squared_error: 1.8668e-04 - val_loss: 0.0088 - val_mean_squared_error: 1.1795e-04
# Epoch 37/40
# 202/202 [==============================] - 10s 48ms/step - loss: 0.0087 - mean_squared_error: 1.8666e-04 - val_loss: 0.0100 - val_mean_squared_error: 1.4620e-04
# Epoch 38/40
# 202/202 [==============================] - 10s 49ms/step - loss: 0.0086 - mean_squared_error: 1.8595e-04 - val_loss: 0.0100 - val_mean_squared_error: 1.8657e-04
# Epoch 39/40
# 202/202 [==============================] - 10s 49ms/step - loss: 0.0087 - mean_squared_error: 1.8737e-04 - val_loss: 0.0113 - val_mean_squared_error: 1.7960e-04
# Epoch 40/40
# 202/202 [==============================] - 10s 50ms/step - loss: 0.0086 - mean_squared_error: 1.8340e-04 - val_loss: 0.0102 - val_mean_squared_error: 1.8685e-04
# ############################################### LBSF ###############################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#
################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Epoch 1/40
# 339/339 [==============================] - 21s 51ms/step - loss: 0.0382 - mean_squared_error: 0.0052 - val_loss: 0.0333 - val_mean_squared_error: 0.0015
# Epoch 2/40
# 339/339 [==============================] - 17s 49ms/step - loss: 0.0162 - mean_squared_error: 4.8996e-04 - val_loss: 0.0188 - val_mean_squared_error: 5.3288e-04
# Epoch 3/40
# 339/339 [==============================] - 17s 49ms/step - loss: 0.0151 - mean_squared_error: 4.1114e-04 - val_loss: 0.0178 - val_mean_squared_error: 4.9864e-04
# Epoch 4/40
# 339/339 [==============================] - 17s 50ms/step - loss: 0.0142 - mean_squared_error: 3.7575e-04 - val_loss: 0.0174 - val_mean_squared_error: 4.8809e-04
# Epoch 5/40
# 339/339 [==============================] - 17s 49ms/step - loss: 0.0140 - mean_squared_error: 3.6563e-04 - val_loss: 0.0209 - val_mean_squared_error: 6.3928e-04
# Epoch 6/40
# 339/339 [==============================] - 17s 49ms/step - loss: 0.0136 - mean_squared_error: 3.4955e-04 - val_loss: 0.0211 - val_mean_squared_error: 6.7283e-04
# Epoch 7/40
# 339/339 [==============================] - 17s 49ms/step - loss: 0.0132 - mean_squared_error: 3.3256e-04 - val_loss: 0.0183 - val_mean_squared_error: 5.3563e-04
# Epoch 8/40
# 339/339 [==============================] - 17s 50ms/step - loss: 0.0129 - mean_squared_error: 3.2010e-04 - val_loss: 0.0175 - val_mean_squared_error: 5.1185e-04
# Epoch 9/40
# 339/339 [==============================] - 17s 48ms/step - loss: 0.0128 - mean_squared_error: 3.1736e-04 - val_loss: 0.0173 - val_mean_squared_error: 4.9345e-04
# Epoch 10/40
# 339/339 [==============================] - 17s 48ms/step - loss: 0.0127 - mean_squared_error: 3.0980e-04 - val_loss: 0.0182 - val_mean_squared_error: 5.4433e-04
# Epoch 11/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0124 - mean_squared_error: 3.0284e-04 - val_loss: 0.0157 - val_mean_squared_error: 4.2110e-04
# Epoch 12/40
# 339/339 [==============================] - 17s 49ms/step - loss: 0.0122 - mean_squared_error: 2.9348e-04 - val_loss: 0.0177 - val_mean_squared_error: 5.0969e-04
# Epoch 13/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0122 - mean_squared_error: 2.9173e-04 - val_loss: 0.0164 - val_mean_squared_error: 4.5595e-04
# Epoch 14/40
# 339/339 [==============================] - 17s 49ms/step - loss: 0.0121 - mean_squared_error: 2.8713e-04 - val_loss: 0.0143 - val_mean_squared_error: 3.5211e-04
# Epoch 15/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0119 - mean_squared_error: 2.7790e-04 - val_loss: 0.0149 - val_mean_squared_error: 3.8689e-04
# Epoch 16/40
# 339/339 [==============================] - 17s 49ms/step - loss: 0.0117 - mean_squared_error: 2.7651e-04 - val_loss: 0.0166 - val_mean_squared_error: 4.7722e-04
# Epoch 17/40
# 339/339 [==============================] - 17s 49ms/step - loss: 0.0119 - mean_squared_error: 2.8214e-04 - val_loss: 0.0154 - val_mean_squared_error: 4.0817e-04
# Epoch 18/40
# 339/339 [==============================] - 17s 48ms/step - loss: 0.0115 - mean_squared_error: 2.7043e-04 - val_loss: 0.0156 - val_mean_squared_error: 4.1876e-04
# Epoch 19/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0118 - mean_squared_error: 2.7433e-04 - val_loss: 0.0157 - val_mean_squared_error: 4.2470e-04
# Epoch 20/40
# 339/339 [==============================] - 17s 48ms/step - loss: 0.0116 - mean_squared_error: 2.7217e-04 - val_loss: 0.0159 - val_mean_squared_error: 4.3629e-04
# Epoch 21/40
# 339/339 [==============================] - 16s 47ms/step - loss: 0.0120 - mean_squared_error: 2.8101e-04 - val_loss: 0.0150 - val_mean_squared_error: 3.9783e-04
# Epoch 22/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0113 - mean_squared_error: 2.6392e-04 - val_loss: 0.0149 - val_mean_squared_error: 3.8680e-04
# Epoch 23/40
# 339/339 [==============================] - 16s 47ms/step - loss: 0.0112 - mean_squared_error: 2.6145e-04 - val_loss: 0.0150 - val_mean_squared_error: 3.9096e-04
# Epoch 24/40
# 339/339 [==============================] - 17s 48ms/step - loss: 0.0112 - mean_squared_error: 2.5735e-04 - val_loss: 0.0150 - val_mean_squared_error: 3.8304e-04
# Epoch 25/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0115 - mean_squared_error: 2.6665e-04 - val_loss: 0.0143 - val_mean_squared_error: 3.5400e-04
# Epoch 26/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0113 - mean_squared_error: 2.6015e-04 - val_loss: 0.0149 - val_mean_squared_error: 3.9570e-04
# Epoch 27/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0114 - mean_squared_error: 2.6320e-04 - val_loss: 0.0144 - val_mean_squared_error: 3.6608e-04
# Epoch 28/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0113 - mean_squared_error: 2.5686e-04 - val_loss: 0.0147 - val_mean_squared_error: 3.8935e-04
# Epoch 29/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0112 - mean_squared_error: 2.5809e-04 - val_loss: 0.0141 - val_mean_squared_error: 3.4493e-04
# Epoch 30/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0110 - mean_squared_error: 2.5160e-04 - val_loss: 0.0140 - val_mean_squared_error: 3.4478e-04
# Epoch 31/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0109 - mean_squared_error: 2.4990e-04 - val_loss: 0.0139 - val_mean_squared_error: 3.3534e-04
# Epoch 32/40
# 339/339 [==============================] - 17s 48ms/step - loss: 0.0110 - mean_squared_error: 2.4848e-04 - val_loss: 0.0136 - val_mean_squared_error: 3.2352e-04
# Epoch 33/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0111 - mean_squared_error: 2.5199e-04 - val_loss: 0.0139 - val_mean_squared_error: 3.4361e-04
# Epoch 34/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0110 - mean_squared_error: 2.4960e-04 - val_loss: 0.0144 - val_mean_squared_error: 3.7110e-04
# Epoch 35/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0108 - mean_squared_error: 2.4556e-04 - val_loss: 0.0142 - val_mean_squared_error: 3.5852e-04
# Epoch 36/40
# 339/339 [==============================] - 17s 48ms/step - loss: 0.0109 - mean_squared_error: 2.4768e-04 - val_loss: 0.0142 - val_mean_squared_error: 3.6054e-04
# Epoch 37/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0107 - mean_squared_error: 2.4309e-04 - val_loss: 0.0137 - val_mean_squared_error: 3.3434e-04
# Epoch 38/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0107 - mean_squared_error: 2.4294e-04 - val_loss: 0.0143 - val_mean_squared_error: 3.6047e-04
# Epoch 39/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0107 - mean_squared_error: 2.4020e-04 - val_loss: 0.0137 - val_mean_squared_error: 3.2927e-04
# Epoch 40/40
# 339/339 [==============================] - 16s 48ms/step - loss: 0.0107 - mean_squared_error: 2.4109e-04 - val_loss: 0.0155 - val_mean_squared_error: 4.2461e-04

# %% [markdown]
# ## Evaluación

# %%
from rtaUtils.experiment import report_columns
for airport in airport_list:
    print(airport.center(100, '#'))
    ### Model configuration #######################################################
    model_type   = f'LSTM_{airport}'
    months       = '*' # 20220[12]
    # airport      = 'EDDF'
    glob_text    = f'{months}-{airport}'

    experimento = experiment.ExperimentVanilla(
        lookback=lookback,
        sampling=sampling,
        model_config=model_config,
        months=months, 
        airport=airport,
        features=feat_dict,
        model_type=model_type
    )

    experimento.load_model('best')

    experimento.evaluate(from_parquet=True, print_err=True)
    experimento.evaluate_at_times()

    experimento.get_evaluation_results('wide')\
           .to_csv(f'./results/{model_type}_s{sampling}_lb{lookback}_u{n_units}.csv', 
                 header=True,index=False, encoding='utf8')
# Out:
# ################################################LEBL################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 23/23 [==============================] - 1s 22ms/step
# RTA ===================================
# Test set          | MAE:        101.522
#                   | RMSE:       149.116
#                   | Mean:       -11.888
#                   | MAPE:        58.999
#                   | Muestra:      2,937
# test: Finalizado
# ################################################LPPT################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 24/24 [==============================] - 1s 19ms/step
# RTA ===================================
# Test set          | MAE:        118.412
#                   | RMSE:       206.862
#                   | Mean:       -16.132
#                   | MAPE:        35.373
#                   | Muestra:      2,981
# test: Finalizado
# ################################################LFPO################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 77/77 [==============================] - 2s 21ms/step
# RTA ===================================
# Test set          | MAE:        185.635
#                   | RMSE:       288.871
#                   | Mean:        63.278
#                   | MAPE:        29.578
#                   | Muestra:      9,830
# test: Finalizado
# ################################################LFPG################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 78/78 [==============================] - 2s 20ms/step
# RTA ===================================
# Test set          | MAE:        152.009
#                   | RMSE:       210.305
#                   | Mean:        37.786
#                   | MAPE:        19.917
#                   | Muestra:      9,915
# test: Finalizado
# ################################################EGLL################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 56/56 [==============================] - 2s 21ms/step
# RTA ===================================
# Test set          | MAE:        212.000
#                   | RMSE:       286.963
#                   | Mean:       -13.453
#                   | MAPE:        24.943
#                   | Muestra:      7,093
# test: Finalizado
# ################################################LPPR################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 22/22 [==============================] - 1s 25ms/step
# RTA ===================================
# Test set          | MAE:         79.889
#                   | RMSE:       114.913
#                   | Mean:       -13.479
#                   | MAPE:        52.147
#                   | Muestra:      2,732
# test: Finalizado
# ################################################EDDF################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 132/132 [==============================] - 4s 29ms/step
# RTA ===================================
# Test set          | MAE:        217.948
#                   | RMSE:       282.130
#                   | Mean:       -16.671
#                   | MAPE:        35.031
#                   | Muestra:     16,834
# test: Finalizado
# ################################################EBBR################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 109/109 [==============================] - 4s 29ms/step
# RTA ===================================
# Test set          | MAE:        224.420
#                   | RMSE:       339.579
#                   | Mean:        68.203
#                   | MAPE:        28.096
#                   | Muestra:     13,908
# test: Finalizado
# ################################################EHAM################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 123/123 [==============================] - 4s 29ms/step
# RTA ===================================
# Test set          | MAE:        205.315
#                   | RMSE:       280.095
#                   | Mean:        21.856
#                   | MAPE:        26.846
#                   | Muestra:     15,737
# test: Finalizado
# ################################################LEBB################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 6/6 [==============================] - 1s 16ms/step
# RTA ===================================
# Test set          | MAE:         80.490
#                   | RMSE:       135.771
#                   | Mean:        -4.470
#                   | MAPE:       212.324
#                   | Muestra:        678
# test: Finalizado
# ################################################LIRF################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 56/56 [==============================] - 2s 28ms/step
# RTA ===================================
# Test set          | MAE:        178.704
#                   | RMSE:       266.340
#                   | Mean:        30.474
#                   | MAPE:        19.578
#                   | Muestra:      7,076
# test: Finalizado
# ################################################EDDM################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 137/137 [==============================] - 5s 29ms/step
# RTA ===================================
# Test set          | MAE:        232.372
#                   | RMSE:       300.673
#                   | Mean:        20.188
#                   | MAPE:        28.596
#                   | Muestra:     17,415
# test: Finalizado
# ################################################EGKK################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 67/67 [==============================] - 2s 29ms/step
# RTA ===================================
# Test set          | MAE:        197.847
#                   | RMSE:       267.852
#                   | Mean:       -11.514
#                   | MAPE:        23.786
#                   | Muestra:      8,514
# test: Finalizado
# ################################################LEVC################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 1/1 [==============================] - 1s 503ms/step
# RTA ===================================
# Test set          | MAE:        339.239
#                   | RMSE:       395.553
#                   | Mean:        52.210
#                   | MAPE:       812.160
#                   | Muestra:         41
# test: Finalizado
# ################################################LSGG################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 82/82 [==============================] - 3s 28ms/step
# RTA ===================================
# Test set          | MAE:        103.817
#                   | RMSE:       144.043
#                   | Mean:       -13.736
#                   | MAPE:        22.995
#                   | Muestra:     10,399
# test: Finalizado
# ################################################LECO################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 20/20 [==============================] - 1s 24ms/step
# RTA ===================================
# Test set          | MAE:         79.254
#                   | RMSE:       148.178
#                   | Mean:        -1.807
#                   | MAPE:        60.748
#                   | Muestra:      2,470
# test: Finalizado
# ################################################LIMC################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 95/95 [==============================] - 3s 29ms/step
# RTA ===================================
# Test set          | MAE:        185.527
#                   | RMSE:       244.593
#                   | Mean:        -6.391
#                   | MAPE:        41.061
#                   | Muestra:     12,113
# test: Finalizado
# ################################################EIDW################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 67/67 [==============================] - 3s 29ms/step
# RTA ===================================
# Test set          | MAE:        216.387
#                   | RMSE:       281.844
#                   | Mean:        36.697
#                   | MAPE:        26.479
#                   | Muestra:      8,453
# test: Finalizado
# ################################################LFML################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 56/56 [==============================] - 2s 27ms/step
# RTA ===================================
# Test set          | MAE:        143.320
#                   | RMSE:       284.977
#                   | Mean:        16.792
#                   | MAPE:        28.702
#                   | Muestra:      7,114
# test: Finalizado
# ################################################LEZL################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 17/17 [==============================] - 1s 23ms/step
# RTA ===================================
# Test set          | MAE:         65.999
#                   | RMSE:       104.452
#                   | Mean:         6.354
#                   | MAPE:        69.632
#                   | Muestra:      2,088
# test: Finalizado
# ################################################LOWW################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 149/149 [==============================] - 5s 29ms/step
# RTA ===================================
# Test set          | MAE:        287.224
#                   | RMSE:       435.628
#                   | Mean:       138.469
#                   | MAPE:        27.254
#                   | Muestra:     19,055
# test: Finalizado
# ################################################LIPZ################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 109/109 [==============================] - 4s 29ms/step
# RTA ===================================
# Test set          | MAE:        203.362
#                   | RMSE:       276.061
#                   | Mean:       -48.134
#                   | MAPE:        23.498
#                   | Muestra:     13,845
# test: Finalizado
# ################################################LIPE################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 97/97 [==============================] - 3s 29ms/step
# RTA ===================================
# Test set          | MAE:        209.383
#                   | RMSE:       278.228
#                   | Mean:        47.871
#                   | MAPE:        34.019
#                   | Muestra:     12,333
# test: Finalizado
# ################################################LFLL################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 67/67 [==============================] - 2s 28ms/step
# RTA ===================================
# Test set          | MAE:        110.741
#                   | RMSE:       174.214
#                   | Mean:         6.942
#                   | MAPE:        19.665
#                   | Muestra:      8,521
# test: Finalizado
# ################################################EDDL################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 115/115 [==============================] - 4s 29ms/step
# RTA ===================================
# Test set          | MAE:        274.615
#                   | RMSE:       422.986
#                   | Mean:        85.762
#                   | MAPE:        22.829
#                   | Muestra:     14,710
# test: Finalizado
# ################################################EDDB################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 150/150 [==============================] - 5s 29ms/step
# RTA ===================================
# Test set          | MAE:        254.633
#                   | RMSE:       381.932
#                   | Mean:        86.950
#                   | MAPE:        17.489
#                   | Muestra:     19,177
# test: Finalizado
# ################################################LTFM################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 154/154 [==============================] - 5s 30ms/step
# RTA ===================================
# Test set          | MAE:        277.561
#                   | RMSE:       403.274
#                   | Mean:       110.812
#                   | MAPE:        19.844
#                   | Muestra:     19,702
# test: Finalizado
# ################################################LFMN################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 57/57 [==============================] - 2s 28ms/step
# RTA ===================================
# Test set          | MAE:        175.550
#                   | RMSE:       270.715
#                   | Mean:        50.871
#                   | MAPE:        23.527
#                   | Muestra:      7,235
# test: Finalizado
# ################################################LFRS################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 35/35 [==============================] - 1s 27ms/step
# RTA ===================================
# Test set          | MAE:        118.343
#                   | RMSE:       157.839
#                   | Mean:        15.921
#                   | MAPE:        35.624
#                   | Muestra:      4,431
# test: Finalizado
# ################################################LROP################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 147/147 [==============================] - 5s 30ms/step
# RTA ===================================
# Test set          | MAE:        292.228
#                   | RMSE:       371.593
#                   | Mean:       162.555
#                   | MAPE:        16.161
#                   | Muestra:     18,808
# test: Finalizado
# ################################################EDDP################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 129/129 [==============================] - 4s 28ms/step
# RTA ===================================
# Test set          | MAE:        181.289
#                   | RMSE:       334.946
#                   | Mean:        48.294
#                   | MAPE:        23.598
#                   | Muestra:     16,453
# test: Finalizado
# ################################################LGAV################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 66/66 [==============================] - 2s 28ms/step
# RTA ===================================
# Test set          | MAE:        283.067
#                   | RMSE:       387.355
#                   | Mean:        89.207
#                   | MAPE:        31.434
#                   | Muestra:      8,335
# test: Finalizado
# ################################################EDDH################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 84/84 [==============================] - 3s 28ms/step
# RTA ===================================
# Test set          | MAE:        201.222
#                   | RMSE:       251.584
#                   | Mean:       -86.758
#                   | MAPE:        34.388
#                   | Muestra:     10,717
# test: Finalizado
# ################################################LHBP################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 100/100 [==============================] - 3s 28ms/step
# RTA ===================================
# Test set          | MAE:        243.840
#                   | RMSE:       311.399
#                   | Mean:        54.796
#                   | MAPE:        14.279
#                   | Muestra:     12,730
# test: Finalizado
# ################################################EKCH################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 82/82 [==============================] - 3s 28ms/step
# RTA ===================================
# Test set          | MAE:        199.874
#                   | RMSE:       268.615
#                   | Mean:       -17.291
#                   | MAPE:        15.213
#                   | Muestra:     10,461
# test: Finalizado
# ################################################EGCC################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 41/41 [==============================] - 2s 27ms/step
# RTA ===================================
# Test set          | MAE:        254.587
#                   | RMSE:       310.708
#                   | Mean:         0.012
#                   | MAPE:        25.491
#                   | Muestra:      5,231
# test: Finalizado
# ################################################ELLX################################################
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 20
#       8 glob_text    = f'{months}-{airport}'
#      10 experimento = experiment.ExperimentVanilla(
#      11     lookback=lookback,
#      12     sampling=sampling,
#    (...)
#      17     model_type=model_type
#      18 )
# ---> 20 experimento.load_model('best')
#      22 experimento.evaluate(from_parquet=True, print_err=True)
#      23 experimento.evaluate_at_times()
#
# File c:\Users\Jorge\Jupyter Notebooks\tesis.kdd_copia - copia\rtaUtils\experiment.py:111, in Experiment.load_model(self, name)
#     103 def load_model(self, name: str = 'last'):
#     104     """Loads a model checkpoint
#     105
#     106     The number of trained epochs is updated accordingly.
#    (...)
#     109         name: Name of the model. Can be either 'last', 'best' or a custom file name
#     110     """
# --> 111     self.model = tf.keras.models.load_model(self.model_path / f'{name}.h5')
#     113     try:
#     114         logs = pd.read_csv(self.model_path_log)
#
# File c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\Jorge\anaconda3\envs\tf\lib\site-packages\keras\saving\save.py:226, in load_model(filepath, custom_objects, compile, options)
#     224 if isinstance(filepath_str, str):
#     225     if not tf.io.gfile.exists(filepath_str):
# --> 226         raise IOError(
#     227             f"No file or directory found at {filepath_str}"
#     228         )
#     230     if tf.io.gfile.isdir(filepath_str):
#     231         return saved_model_load.load(
#     232             filepath_str, compile, options
#     233         )
#
# OSError: No file or directory found at rtaUtils\..\models\LSTM_ELLX_s30_lb64_u20\best.h5

# %% [markdown]
# ## Generación de informe

# %%
from rtaUtils.experiment import report_columns
report_df_long = pd.DataFrame.from_dict(
    experimento.results, orient='index',
    columns=['dataset','time',*report_columns])
report_df = report_df_long.pivot_table(index=['dataset'], columns=['time'], values=report_columns)
report_df.columns = [' '.join((str(y) for y in x)) 
                     for x in report_df.columns.to_flat_index()]
report_df = report_df.reset_index()
# report_df[[x for x in report_df.columns if report_columns[0] in x]]

# %%
report_df

# %%
report_df.to_csv(f'./results/{model_type}_s{sampling}_lb{lookback}_u{n_units}.csv', 
                 header=True, encoding='utf8')

# %%
# Exportar a CSV
experimento.get_evaluation_results('wide')\
           .to_csv(f'./results/{model_type}_s{sampling}_lb{lookback}_u{n_units}.csv', 
                 header=True,index=False, encoding='utf8')

# %% [markdown]
# ## Visualización

# %%
import plotly.express as px

# %%
report_df = pd.read_csv(f'./results/{model_type}_s{sampling}_lb{lookback}_u{n_units}.csv', 
                        header=0, encoding='utf8')

# %%
vis = pd.merge(
    report_df[['MAE all','RMSE all','MAPE all', 'Mean all','Sample all','dataset']],
    pd.read_csv('./data/airports.csv', sep = ','),
    left_on='dataset', right_on='id'
)

# %%
td = data_loading.load_final_data(months, 'test')[['aerodromeOfDeparture', 'fpId']].drop_duplicates()\
              .groupby('aerodromeOfDeparture').count()

vis = pd.merge(vis, td, left_on='dataset', right_on='aerodromeOfDeparture')

# %% [raw]
# td = test_data[['aerodromeOfDeparture', 'fpId']].drop_duplicates()\
#               .groupby('aerodromeOfDeparture').count()
#
# vis = pd.merge(vis, td, left_on='airport', right_on='aerodromeOfDeparture')

# %%
px.scatter_mapbox(vis, 'lat', 'lon', zoom=3.6,width=950, height=750,
                  mapbox_style="open-street-map", opacity = 1,
                  color = 'MAE all', size='fpId',
#                   range_color=(50,300),
                  # color_continuous_scale='RdYlGn_r', #'bluered' 'Portland'
                  # color_continuous_midpoint=150,
                  hover_data = {'MAE all':':.3f',
                                'RMSE all':':.3f',
                                'Sample all':':.3f'},
                  hover_name='dataset'
                 )

# %%
px.scatter_mapbox(vis, 'lat', 'lon', zoom=3.6,width=950, height=750,
                  mapbox_style="open-street-map", opacity = 1,
                  color = 'MAPE all', size='fpId',
                  # range_color=(0,0.2),
                  # color_continuous_scale='RdYlGn_r', #'bluered' 'Portland'
                  # color_continuous_midpoint=150,
                  hover_data = {'MAE all':':.3f',
                                'RMSE all':':.3f'},
                  hover_name='dataset'
                 )
