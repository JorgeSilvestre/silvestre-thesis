# %%
import tensorflow as tf
import pandas as pd
import datetime
import matplotlib.pyplot as plt

import sys
sys.path.append('./rtaUtils')

from rtaUtils import paths, experiment, data_loading

import wandb, os
from wandb.keras import WandbCallback
os.environ["WANDB_SILENT"] = "true"

tf.config.set_visible_devices([], 'GPU')
visible_devices = tf.config.get_visible_devices()
print(visible_devices)
for device in visible_devices:
    assert device.device_type != 'GPU'
    
### Features ##################################################################
numeric_feat = [
    'latitude', 'longitude', 'altitude', 'departureDelay', 'vspeed', 'speed', 
    'day_of_week', 'track', 'wind_dir_degrees', 'wind_speed_kt', 
    'visibility_statute_mi', 'max_temp', 'min_temp', 'clouds', 'hav_distance'
]
categoric_feat = [
    'time_of_day', 'operator', 'aerodromeOfDeparture', 'sky_status'
]
objective = ['RTA']

ts_features = [
    'latitude', 'longitude', 'altitude', 'vspeed', 'speed', 'track', 'hav_distance'
]
nts_features = [
    'departureDelay', 'day_of_week', 'wind_dir_degrees','wind_speed_kt', 
    'visibility_statute_mi', 'max_temp', 'min_temp', 'time_of_day', 'operator', 
    'aerodromeOfDeparture', 'sky_status', 'clouds'
]

feat_dict = dict(
    numeric=numeric_feat,
    categoric=categoric_feat,
    objective=objective,
    ts=ts_features,
    nts=nts_features
)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
### Experiment setup ##########################################################
n_units      = 20
lookback     = 32
sampling     = 60

epochs       = 30

act_function = 'tanh'
batch_size   = 128
from_parquet = True

model_config = dict(
    n_units=n_units,
    act_function=act_function,
    batch_size=batch_size,
)

### Model configuration #######################################################
model_type   = 'EDFC'
months       = '*' # 20220[12]
airport      = '*'
glob_text    = f'{months}-{airport}'

# %%
dt = datetime.datetime.now().strftime('%m%d_%H%M')

wandb_config = {
    'batch_size' : batch_size,
    'lookback' : lookback,
    'n_units' : n_units,
    'sampling' : sampling,
    'model_type' : model_type
}
wandb.init(project='RTAs', config=wandb_config,
           name=f'{model_type}_s{sampling}_lb{lookback}_u{n_units}_{dt}'           
           # resume='must', id=''
          ) 
wandCallback = WandbCallback(save_model=False)

# %% [markdown]
# ## Entrenamiento

# %%
experimento = experiment.ExperimentEDFC(
    lookback=lookback,
    sampling=sampling,
    model_config=model_config,
    months=months, 
    airport=airport,
    features=feat_dict
)
experimento.init_model()
# experimento.load_model()
experimento.model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 19)]          0
#
#  bidirectional (Bidirectiona  (None, 40)               6400
#  l)
#
#  dense (Dense)               (None, 20)                820
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 7,441
# Trainable params: 7,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = experimento.train(epochs=epochs, from_parquet=from_parquet, add_callbacks = [wandCallback]) 
# add_callbacks = [wandCallback]
# Out:
# WARNING:tensorflow:From C:\Users\Jorge\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# Epoch 1/30
# 7518/7518 [==============================] - 304s 40ms/step - loss: 0.0094 - mean_squared_error: 2.6397e-04 - val_loss: 0.0100 - val_mean_squared_error: 2.0403e-04
# Epoch 2/30
# 7518/7518 [==============================] - 309s 41ms/step - loss: 0.0077 - mean_squared_error: 1.7000e-04 - val_loss: 0.0122 - val_mean_squared_error: 2.9581e-04
# Epoch 3/30
# 7518/7518 [==============================] - 320s 42ms/step - loss: 0.0074 - mean_squared_error: 1.6185e-04 - val_loss: 0.0105 - val_mean_squared_error: 2.2988e-04
# Epoch 4/30
# 7518/7518 [==============================] - 329s 43ms/step - loss: 0.0072 - mean_squared_error: 1.5611e-04 - val_loss: 0.0115 - val_mean_squared_error: 2.7607e-04
# Epoch 5/30
# 7518/7518 [==============================] - 340s 45ms/step - loss: 0.0071 - mean_squared_error: 1.5236e-04 - val_loss: 0.0102 - val_mean_squared_error: 2.2709e-04
# Epoch 6/30
# 7518/7518 [==============================] - 340s 45ms/step - loss: 0.0069 - mean_squared_error: 1.4870e-04 - val_loss: 0.0101 - val_mean_squared_error: 2.2190e-04
# Epoch 7/30
# 7518/7518 [==============================] - 346s 45ms/step - loss: 0.0068 - mean_squared_error: 1.4598e-04 - val_loss: 0.0095 - val_mean_squared_error: 1.9708e-04
# Epoch 8/30
# 7518/7518 [==============================] - 353s 46ms/step - loss: 0.0068 - mean_squared_error: 1.4433e-04 - val_loss: 0.0103 - val_mean_squared_error: 2.4043e-04
# Epoch 9/30
# 7518/7518 [==============================] - 355s 47ms/step - loss: 0.0067 - mean_squared_error: 1.4225e-04 - val_loss: 0.0105 - val_mean_squared_error: 2.3446e-04
# Epoch 10/30
# 7518/7518 [==============================] - 359s 47ms/step - loss: 0.0066 - mean_squared_error: 1.4006e-04 - val_loss: 0.0110 - val_mean_squared_error: 2.5887e-04
# Epoch 11/30
# 7518/7518 [==============================] - 361s 47ms/step - loss: 0.0066 - mean_squared_error: 1.3969e-04 - val_loss: 0.0112 - val_mean_squared_error: 2.7162e-04
# Epoch 12/30
# 7518/7518 [==============================] - 366s 48ms/step - loss: 0.0066 - mean_squared_error: 1.3991e-04 - val_loss: 0.0097 - val_mean_squared_error: 2.0985e-04
# Epoch 13/30
# 7518/7518 [==============================] - 367s 48ms/step - loss: 0.0065 - mean_squared_error: 1.3765e-04 - val_loss: 0.0098 - val_mean_squared_error: 2.0960e-04
# Epoch 14/30
# 7518/7518 [==============================] - 373s 49ms/step - loss: 0.0065 - mean_squared_error: 1.3624e-04 - val_loss: 0.0103 - val_mean_squared_error: 2.3417e-04
# Epoch 15/30
# 7518/7518 [==============================] - 375s 49ms/step - loss: 0.0064 - mean_squared_error: 1.3590e-04 - val_loss: 0.0102 - val_mean_squared_error: 2.2752e-04
# Epoch 16/30
# 7518/7518 [==============================] - 378s 50ms/step - loss: 0.0064 - mean_squared_error: 1.3450e-04 - val_loss: 0.0101 - val_mean_squared_error: 2.2788e-04
# Epoch 17/30
# 7298/7518 [============================>.] - ETA: 10s - loss: 0.0064 - mean_squared_error: 1.3626e-04

# %%
progress = pd.read_csv(experimento.model_path_log)
skip = 0

plt.plot([str(x) for x in range(1+skip,progress.shape[0]+1)], progress['loss'].iloc[skip:], label='loss')
plt.plot([str(x) for x in range(1+skip,progress.shape[0]+1)], progress['val_loss'].iloc[skip:], label='validation loss')
plt.title(f'{model_type}.u{n_units}lb{lookback}s{sampling}')
plt.xlabel('Epochs')
plt.ylabel('MAE')
if progress.shape[0]>10:
    plt.xticks([str(x) for x in range(1+skip,progress.shape[0],progress.shape[0]//5)])
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluación

# %%
experimento = experiment.ExperimentED(
    lookback=lookback,
    sampling=sampling,
    model_config=model_config,
    months=months, 
    airport=airport,
    features=feat_dict
)
experimento.load_model('best')

# %%
experimento.evaluate(from_parquet=from_parquet, print_err=True)

# %%
experimento.evaluate_at_times()

# %%
experimento.evaluate_airports()

# %% [raw]
# # arbitrario
# feat = 'visibility_statute_mi'
# for idx, value in enumerate(sorted(test_data[feat].unique())):
#     data = test_data[test_data[feat] == value].sort_values(by=['fpId','timestamp']).copy()
#
#     if data.size < lookback:
#         continue
#     print(f'({idx+1}/{len(test_data[feat].unique())}) Evaluando {feat}={value}')
#
#     ds = get_windows2(data,lookback,encoders,scaler,numeric_feat,categoric_feat,objective)
#
#     metrics_values = evaluate_model(ds, print_err = True)

# %% [markdown]
# ## Generación de informe

# %%
from rtaUtils.experiment import report_columns
report_df_long = pd.DataFrame.from_dict(
    experimento.results, orient='index',
    columns=['dataset','time',*report_columns])
report_df = report_df_long.pivot_table(index=['dataset'], columns=['time'], values=report_columns)
report_df.columns = [' '.join((str(y) for y in x)) 
                     for x in report_df.columns.to_flat_index()]
report_df = report_df.reset_index()
# report_df[[x for x in report_df.columns if report_columns[0] in x]]

# %%
report_df

# %%
report_df.to_csv(f'./results/{model_type}_s{sampling}_lb{lookback}_u{n_units}.csv', 
                 header=True, encoding='utf8')

# %% [markdown]
# ## Visualización

# %%
import plotly.express as px

# %%
report_df = pd.read_csv(f'./results/{model_type}_s{sampling}_lb{lookback}_u{n_units}.csv', 
                        header=0, encoding='utf8', index_col=0)

# %%
vis = pd.merge(
    report_df[['MAE all','RMSE all','MAPE all', 'StDev all','Mean all','dataset']],
    pd.read_csv('./data/airports.csv', sep = ','),
    left_on='dataset', right_on='id'
)

# %%
td = data_loading.load_final_data(months, 'test')[['aerodromeOfDeparture', 'fpId']].drop_duplicates()\
              .groupby('aerodromeOfDeparture').count()

vis = pd.merge(vis, td, left_on='dataset', right_on='aerodromeOfDeparture')

# %% [raw]
# td = test_data[['aerodromeOfDeparture', 'fpId']].drop_duplicates()\
#               .groupby('aerodromeOfDeparture').count()
#
# vis = pd.merge(vis, td, left_on='airport', right_on='aerodromeOfDeparture')

# %%
report_df

# %%
px.scatter_mapbox(vis, 'lat', 'lon', zoom=3.6,width=950, height=750,
                  mapbox_style="open-street-map", opacity = 1,
                  color = 'MAE all', size='fpId',
#                   range_color=(50,300),
#                   color_continuous_scale='RdYlGn_r', #'bluered' 'Portland'
                  # color_continuous_midpoint=150,
                  hover_data = {'MAE all':':.3f',
                                'RMSE all':':.3f'},
                  hover_name='dataset'
                 )

# %%
px.scatter_mapbox(vis, 'lat', 'lon', zoom=3.6,width=950, height=750,
                  mapbox_style="open-street-map", opacity = 1,
                  color = 'MAPE all', size='fpId',
                  # range_color=(0,0.2),
                  # color_continuous_scale='RdYlGn_r', #'bluered' 'Portland'
                  # color_continuous_midpoint=150,
                  hover_data = {'MAE all':':.3f',
                                'RMSE all':':.3f'},
                  hover_name='dataset'
                 )
